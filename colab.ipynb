# %% [markdown]
# <a href="https://colab.research.google.com/github/mokunosuke/StyleGAN/blob/main/colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Talking Head Anime from a Single Image 2: More Expressive (Manual Poser Tool)
#
# **Instruction**
#
# 1. Run the four cells below, one by one, in order by clicking the "Play" button to the left of it. Wait for each cell to finish before going to the next one.
# 2. Scroll down to the end of the last cell, and play with the GUI.
#
# **Constraints on Images**
#
# 1. Must be an image of a single humanoid anime character.
# 3. The head must be roughly contained in the middle box.
# 5. Must have an alpha channel.
#
# **Links**
#
# * Github repository: http://github.com/pkhungurn/talking-head-anime-2-demo
# * Project writeup: http://pkhungurn.github.io/talking-head-anime-2/

# %%
# Clone the repository
# %cd /content
# !git clone https://github.com/pkhungurn/talking-head-anime-2-demo.git
# Out:
# /content
# Cloning into 'talking-head-anime-2-demo'...
# remote: Enumerating objects: 204, done.
# remote: Counting objects: 100% (78/78), done.
# remote: Compressing objects: 100% (40/40), done.
# remote: Total 204 (delta 48), reused 45 (delta 38), pack-reused 126
# Receiving objects: 100% (204/204), 1.38 MiB | 28.75 MiB/s, done.
# Resolving deltas: 100% (82/82), done.

# %%
# CD into the repository directory.
# %cd /content/talking-head-anime-2-demo
# Out:
# /content/talking-head-anime-2-demo

# %%
# Download model files
# !wget -O data/combiner.pt https://www.dropbox.com/s/at2r3v22xgyoxtk/combiner.pt?dl=0
# !wget -O data/eyebrow_decomposer.pt https://www.dropbox.com/s/pbomb5vgens03rk/eyebrow_decomposer.pt?dl=0
# !wget -O data/eyebrow_morphing_combiner.pt https://www.dropbox.com/s/yk9m5ok03e0ub1f/eyebrow_morphing_combiner.pt?dl=0
# !wget -O data/face_morpher.pt https://www.dropbox.com/s/77sza8qkiwd4qq5/face_morpher.pt?dl=0
# !wget -O data/two_algo_face_rotator.pt https://www.dropbox.com/s/ek261g9sspf0cqi/two_algo_face_rotator.pt?dl=0
# Out:
# --2022-08-27 23:33:36--  https://www.dropbox.com/s/at2r3v22xgyoxtk/combiner.pt?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.4.18, 2620:100:6019:18::a27d:412
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.4.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/at2r3v22xgyoxtk/combiner.pt [following]
# --2022-08-27 23:33:36--  https://www.dropbox.com/s/raw/at2r3v22xgyoxtk/combiner.pt
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc5c845dca2fd7afb924c5c1026d.dl.dropboxusercontent.com/cd/0/inline/Br2hEXrZYI_J_QzcjqU5_e5QBnPbteARcJp2WxKuoEtO4QfQgQ5eCW7GdyU4GQ7CkUS08UbZ7YaA8Wbjrxrci4_yElpaIpraFBgT0oFuhNdRCV-8HPX9Yya8UcKUCzgT0pq3NEFd3oOWfXF5zbjYp_EWTMsUIjQJhPWTWDlSjv65zQ/file# [following]
# --2022-08-27 23:33:36--  https://uc5c845dca2fd7afb924c5c1026d.dl.dropboxusercontent.com/cd/0/inline/Br2hEXrZYI_J_QzcjqU5_e5QBnPbteARcJp2WxKuoEtO4QfQgQ5eCW7GdyU4GQ7CkUS08UbZ7YaA8Wbjrxrci4_yElpaIpraFBgT0oFuhNdRCV-8HPX9Yya8UcKUCzgT0pq3NEFd3oOWfXF5zbjYp_EWTMsUIjQJhPWTWDlSjv65zQ/file
# Resolving uc5c845dca2fd7afb924c5c1026d.dl.dropboxusercontent.com (uc5c845dca2fd7afb924c5c1026d.dl.dropboxusercontent.com)... 162.125.4.15, 2620:100:6019:15::a27d:40f
# Connecting to uc5c845dca2fd7afb924c5c1026d.dl.dropboxusercontent.com (uc5c845dca2fd7afb924c5c1026d.dl.dropboxusercontent.com)|162.125.4.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/Br1hV0fE83ho-bJn3y8XNQXWbuM55vOhZgX2VCGDUAHdpLlSVVZZeiFRKU4NzpAh3bAiAWgFvl8PAksfKlIyGW-sj0WDrbIykG9RySWw1SSA7H7L-fmeNFj9srvDLbd_ks7l78BLSWOOBKX0svOpxdupgoemf7FZlvkkPbKHBJNiePCaWGwp_6GPTsdLc-pymWewoJVNV0tAMXh3k1H9mZJcv15huoJPvCsa5ZnyfO9X09UR9Ku6x0jbU6h06vR_fVhGIHB40Streb3f1MF54RASAbebjPBGjC6MIXKgAlpL0p-GRL3j06kkeDS5mL9Q0LWnGyctRsZCgdhZ9kaFzks0MBNX6uegzeAhI9KLmYiLh1Fw8nuULWBIAjksZwzSzRUTyG5g_rwJk0jhTGIdUvWveZnUa7fnxNltBRtJpOBrCA/file [following]
# --2022-08-27 23:33:37--  https://uc5c845dca2fd7afb924c5c1026d.dl.dropboxusercontent.com/cd/0/inline2/Br1hV0fE83ho-bJn3y8XNQXWbuM55vOhZgX2VCGDUAHdpLlSVVZZeiFRKU4NzpAh3bAiAWgFvl8PAksfKlIyGW-sj0WDrbIykG9RySWw1SSA7H7L-fmeNFj9srvDLbd_ks7l78BLSWOOBKX0svOpxdupgoemf7FZlvkkPbKHBJNiePCaWGwp_6GPTsdLc-pymWewoJVNV0tAMXh3k1H9mZJcv15huoJPvCsa5ZnyfO9X09UR9Ku6x0jbU6h06vR_fVhGIHB40Streb3f1MF54RASAbebjPBGjC6MIXKgAlpL0p-GRL3j06kkeDS5mL9Q0LWnGyctRsZCgdhZ9kaFzks0MBNX6uegzeAhI9KLmYiLh1Fw8nuULWBIAjksZwzSzRUTyG5g_rwJk0jhTGIdUvWveZnUa7fnxNltBRtJpOBrCA/file
# Reusing existing connection to uc5c845dca2fd7afb924c5c1026d.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 139853811 (133M) [application/octet-stream]
# Saving to: ‘data/combiner.pt’
#
# data/combiner.pt    100%[===================>] 133.37M   148MB/s    in 0.9s
#
# 2022-08-27 23:33:39 (148 MB/s) - ‘data/combiner.pt’ saved [139853811/139853811]
#
# --2022-08-27 23:33:39--  https://www.dropbox.com/s/pbomb5vgens03rk/eyebrow_decomposer.pt?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.4.18, 2620:100:6019:18::a27d:412
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.4.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/pbomb5vgens03rk/eyebrow_decomposer.pt [following]
# --2022-08-27 23:33:40--  https://www.dropbox.com/s/raw/pbomb5vgens03rk/eyebrow_decomposer.pt
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ucbc3339c06075b1055467868dc3.dl.dropboxusercontent.com/cd/0/inline/Br1XWNrVPe8OVGwsgFPflxwYXKX-DBL22zjrL97hRrbcQb6tozF3-x6GDUhFX2_EamOGtSMM12YGWeNxI3Bq9AyYYytoqfc5ZrHHj2-PywZBirjQd6Te8beUSxtr1jXUJ8TSpc4srGS5-LMTdFrt1QLIZpjJ7moTAzH7FByNIEZBeQ/file# [following]
# --2022-08-27 23:33:40--  https://ucbc3339c06075b1055467868dc3.dl.dropboxusercontent.com/cd/0/inline/Br1XWNrVPe8OVGwsgFPflxwYXKX-DBL22zjrL97hRrbcQb6tozF3-x6GDUhFX2_EamOGtSMM12YGWeNxI3Bq9AyYYytoqfc5ZrHHj2-PywZBirjQd6Te8beUSxtr1jXUJ8TSpc4srGS5-LMTdFrt1QLIZpjJ7moTAzH7FByNIEZBeQ/file
# Resolving ucbc3339c06075b1055467868dc3.dl.dropboxusercontent.com (ucbc3339c06075b1055467868dc3.dl.dropboxusercontent.com)... 162.125.4.15, 2620:100:6019:15::a27d:40f
# Connecting to ucbc3339c06075b1055467868dc3.dl.dropboxusercontent.com (ucbc3339c06075b1055467868dc3.dl.dropboxusercontent.com)|162.125.4.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/Br3EriRglkwtRTmOSA5QWNq7kDgBQ46onPc2838DC5j0qLAF9Vp2mZED-dvC3oqbL0MgFPgzP9M9royBzYMHy5sYZSZRpVjCitatCHlZcDkpUHS7en4SfrHWpe0vF5ZUzaHQ6yDbdk2H5nfJxx7u69d-4aYUIoT_5mK0oLwpAlEsuSDtXi5dGpCF7I17sFzFiHBhg7doYgj62fjM-OgcVnvRRefq8lqpHFqmrAyp4ji8CAPbJnxHV4LSG2ocsdH5rn8tP7aJDYviBMYmBsVAP1dF4tKzltGKvETKjLI95wa8vm0r8imaBcZOwHPTwMzb0nz-dLDwx-sYsiK3Do2JM6iEXZbkB9jnwhZjuTgMm8Zuf37z600_tBA52IuQG7S3FtJOP9TkICqK-L1fH-td9StTP9J3DNtUL6PBMZRCdKLv3A/file [following]
# --2022-08-27 23:33:40--  https://ucbc3339c06075b1055467868dc3.dl.dropboxusercontent.com/cd/0/inline2/Br3EriRglkwtRTmOSA5QWNq7kDgBQ46onPc2838DC5j0qLAF9Vp2mZED-dvC3oqbL0MgFPgzP9M9royBzYMHy5sYZSZRpVjCitatCHlZcDkpUHS7en4SfrHWpe0vF5ZUzaHQ6yDbdk2H5nfJxx7u69d-4aYUIoT_5mK0oLwpAlEsuSDtXi5dGpCF7I17sFzFiHBhg7doYgj62fjM-OgcVnvRRefq8lqpHFqmrAyp4ji8CAPbJnxHV4LSG2ocsdH5rn8tP7aJDYviBMYmBsVAP1dF4tKzltGKvETKjLI95wa8vm0r8imaBcZOwHPTwMzb0nz-dLDwx-sYsiK3Do2JM6iEXZbkB9jnwhZjuTgMm8Zuf37z600_tBA52IuQG7S3FtJOP9TkICqK-L1fH-td9StTP9J3DNtUL6PBMZRCdKLv3A/file
# Reusing existing connection to ucbc3339c06075b1055467868dc3.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 125943711 (120M) [application/octet-stream]
# Saving to: ‘data/eyebrow_decomposer.pt’
#
# data/eyebrow_decomp 100%[===================>] 120.11M   189MB/s    in 0.6s
#
# 2022-08-27 23:33:42 (189 MB/s) - ‘data/eyebrow_decomposer.pt’ saved [125943711/125943711]
#
# --2022-08-27 23:33:42--  https://www.dropbox.com/s/yk9m5ok03e0ub1f/eyebrow_morphing_combiner.pt?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.4.18, 2620:100:6019:18::a27d:412
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.4.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/yk9m5ok03e0ub1f/eyebrow_morphing_combiner.pt [following]
# --2022-08-27 23:33:42--  https://www.dropbox.com/s/raw/yk9m5ok03e0ub1f/eyebrow_morphing_combiner.pt
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uca7d63520c6e783733e8f149bf0.dl.dropboxusercontent.com/cd/0/inline/Br3lHwFG8nlV0q-q9WpDa0nYG9Qas4U7JTQSCOIVl98ASMo-0SdmgnSz5vKyhkCXJOXurcCT4fPDh3JaJAqCKGkWGTMbT4NtLJSbJB99GHDpyKGxZMBowt8PD7FsEBHVMhCUxbcsOA6DOv7jpYP-Top06JRxl2gz4NR4czEKHVV9xQ/file# [following]
# --2022-08-27 23:33:42--  https://uca7d63520c6e783733e8f149bf0.dl.dropboxusercontent.com/cd/0/inline/Br3lHwFG8nlV0q-q9WpDa0nYG9Qas4U7JTQSCOIVl98ASMo-0SdmgnSz5vKyhkCXJOXurcCT4fPDh3JaJAqCKGkWGTMbT4NtLJSbJB99GHDpyKGxZMBowt8PD7FsEBHVMhCUxbcsOA6DOv7jpYP-Top06JRxl2gz4NR4czEKHVV9xQ/file
# Resolving uca7d63520c6e783733e8f149bf0.dl.dropboxusercontent.com (uca7d63520c6e783733e8f149bf0.dl.dropboxusercontent.com)... 162.125.4.15, 2620:100:6019:15::a27d:40f
# Connecting to uca7d63520c6e783733e8f149bf0.dl.dropboxusercontent.com (uca7d63520c6e783733e8f149bf0.dl.dropboxusercontent.com)|162.125.4.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/Br3DoTWKF_s0MfJ_s0d6vflOD5qi2hiCLAQ5zR9s9CpxnoFtnY9H79yHuFqzSjjsxHWRf2sJIF8lR6_eze5b4kWjETDiUb6gocY_NNnDLaL73_d_p6coDtyWaukH0SN8X3yJhg5wZFM1x7k2EwNmeYruIONyIBkryM8ZplTf3gFbVlHVkUE0qZQRzmL5VNsi_svNRLeH0s7Z-ZSTrjN2wA1K2ovmKYJJoXAA_DPSkGp2rx9EMzLK7Rs9AiFamRjFzwKmxiE4LIoW3w71-xaW6-Jh38tJfBPB6ZqBoV4UqBF7GPvm0k3Om-r1FsOewNsC8ZEZHo9ZPwlDZ5oy8lPhpS7uZnTnpxIK_uUNSaIaiZdnxeaB8qXU15aOGGZIZuq6YoOnZ1CWN6GoyB3fgEHrUWFOcf7_BYm3zeyqRPSNQU6asA/file [following]
# --2022-08-27 23:33:43--  https://uca7d63520c6e783733e8f149bf0.dl.dropboxusercontent.com/cd/0/inline2/Br3DoTWKF_s0MfJ_s0d6vflOD5qi2hiCLAQ5zR9s9CpxnoFtnY9H79yHuFqzSjjsxHWRf2sJIF8lR6_eze5b4kWjETDiUb6gocY_NNnDLaL73_d_p6coDtyWaukH0SN8X3yJhg5wZFM1x7k2EwNmeYruIONyIBkryM8ZplTf3gFbVlHVkUE0qZQRzmL5VNsi_svNRLeH0s7Z-ZSTrjN2wA1K2ovmKYJJoXAA_DPSkGp2rx9EMzLK7Rs9AiFamRjFzwKmxiE4LIoW3w71-xaW6-Jh38tJfBPB6ZqBoV4UqBF7GPvm0k3Om-r1FsOewNsC8ZEZHo9ZPwlDZ5oy8lPhpS7uZnTnpxIK_uUNSaIaiZdnxeaB8qXU15aOGGZIZuq6YoOnZ1CWN6GoyB3fgEHrUWFOcf7_BYm3zeyqRPSNQU6asA/file
# Reusing existing connection to uca7d63520c6e783733e8f149bf0.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 126169111 (120M) [application/octet-stream]
# Saving to: ‘data/eyebrow_morphing_combiner.pt’
#
# data/eyebrow_morphi 100%[===================>] 120.32M   117MB/s    in 1.0s
#
# 2022-08-27 23:33:44 (117 MB/s) - ‘data/eyebrow_morphing_combiner.pt’ saved [126169111/126169111]
#
# --2022-08-27 23:33:44--  https://www.dropbox.com/s/77sza8qkiwd4qq5/face_morpher.pt?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.4.18, 2620:100:6019:18::a27d:412
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.4.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/77sza8qkiwd4qq5/face_morpher.pt [following]
# --2022-08-27 23:33:45--  https://www.dropbox.com/s/raw/77sza8qkiwd4qq5/face_morpher.pt
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc659aa0ac7958706004f7f587b3.dl.dropboxusercontent.com/cd/0/inline/Br0qf2UY5TJyCTykewaTyGGuR1v6DCy61byNgpOpuLBvdFthEzDnEE3dd9rCZyV_xffRZvdzcUQOQUAMZ8UpblRlj66t-U8zjf16VhCl9QnntjN09yRjLlWb4cOGOj_8ARgGzM9P7KSFYO8UoOrxfqvEl2JSdKmXcKG7amPQAo6WZw/file# [following]
# --2022-08-27 23:33:45--  https://uc659aa0ac7958706004f7f587b3.dl.dropboxusercontent.com/cd/0/inline/Br0qf2UY5TJyCTykewaTyGGuR1v6DCy61byNgpOpuLBvdFthEzDnEE3dd9rCZyV_xffRZvdzcUQOQUAMZ8UpblRlj66t-U8zjf16VhCl9QnntjN09yRjLlWb4cOGOj_8ARgGzM9P7KSFYO8UoOrxfqvEl2JSdKmXcKG7amPQAo6WZw/file
# Resolving uc659aa0ac7958706004f7f587b3.dl.dropboxusercontent.com (uc659aa0ac7958706004f7f587b3.dl.dropboxusercontent.com)... 162.125.4.15, 2620:100:6023:15::a27d:430f
# Connecting to uc659aa0ac7958706004f7f587b3.dl.dropboxusercontent.com (uc659aa0ac7958706004f7f587b3.dl.dropboxusercontent.com)|162.125.4.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/Br3VEIV7sPV5TfXxGVSy41jiHGeeVokp0Gkx-jwyWvafy69K5mqrG2bK7avrSEL8oPsmVY9NseaD-2j9h5PgumfXZbp22_o58gdK6bE8IZZUsc39itHLg12zAgGE6A9oMkH_FnbjgbgQj3Mz83FS3WwffYb_2D-XK0splhOyIbkxnNj23HqjGULJSzIruZLwALEYcyEwgZEvgn9_H_AiSdA42Dlit3P7-_h9wPQyO8ur67KKxqLrAdqDSzjRKhTqOPZy078mKVAe-LNbu5Xsx6V4pENOqWXeEx_gfKPbCbgO1RDkOPkIzK9W62DlsARq99dOpMaTJFYXcxY1ct6PSQI-W3QAdNcTjiQPwd8I9VG9Kb9U0GlftYSWkk35xSyqO76d95ZJoITFDLDHBQjgrcmxVl5HNFGJDGo66u9RJ6OlFQ/file [following]
# --2022-08-27 23:33:45--  https://uc659aa0ac7958706004f7f587b3.dl.dropboxusercontent.com/cd/0/inline2/Br3VEIV7sPV5TfXxGVSy41jiHGeeVokp0Gkx-jwyWvafy69K5mqrG2bK7avrSEL8oPsmVY9NseaD-2j9h5PgumfXZbp22_o58gdK6bE8IZZUsc39itHLg12zAgGE6A9oMkH_FnbjgbgQj3Mz83FS3WwffYb_2D-XK0splhOyIbkxnNj23HqjGULJSzIruZLwALEYcyEwgZEvgn9_H_AiSdA42Dlit3P7-_h9wPQyO8ur67KKxqLrAdqDSzjRKhTqOPZy078mKVAe-LNbu5Xsx6V4pENOqWXeEx_gfKPbCbgO1RDkOPkIzK9W62DlsARq99dOpMaTJFYXcxY1ct6PSQI-W3QAdNcTjiQPwd8I9VG9Kb9U0GlftYSWkk35xSyqO76d95ZJoITFDLDHBQjgrcmxVl5HNFGJDGo66u9RJ6OlFQ/file
# Reusing existing connection to uc659aa0ac7958706004f7f587b3.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 126445607 (121M) [application/octet-stream]
# Saving to: ‘data/face_morpher.pt’
#
# data/face_morpher.p 100%[===================>] 120.59M   162MB/s    in 0.7s
#
# 2022-08-27 23:33:46 (162 MB/s) - ‘data/face_morpher.pt’ saved [126445607/126445607]
#
# --2022-08-27 23:33:47--  https://www.dropbox.com/s/ek261g9sspf0cqi/two_algo_face_rotator.pt?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.4.18, 2620:100:6019:18::a27d:412
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.4.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/ek261g9sspf0cqi/two_algo_face_rotator.pt [following]
# --2022-08-27 23:33:47--  https://www.dropbox.com/s/raw/ek261g9sspf0cqi/two_algo_face_rotator.pt
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ucd4ee8b4a27d469b30a12f45096.dl.dropboxusercontent.com/cd/0/inline/Br0IWsKE8rwgeO09GymPB0KNfoJMBADfBZLmMFcIq5nRJuBWW_Cb61n3aL6lLYidjFGWSWujdRbFIJ0EHQwVsIHga2sqMvcefhY9bPjCi286ny-94IsnRV1NYh-B0FvZq_BAWZkRn2K8l1dYXVc3Am7i3PAZFlUxHwWtsL95EjHE6g/file# [following]
# --2022-08-27 23:33:47--  https://ucd4ee8b4a27d469b30a12f45096.dl.dropboxusercontent.com/cd/0/inline/Br0IWsKE8rwgeO09GymPB0KNfoJMBADfBZLmMFcIq5nRJuBWW_Cb61n3aL6lLYidjFGWSWujdRbFIJ0EHQwVsIHga2sqMvcefhY9bPjCi286ny-94IsnRV1NYh-B0FvZq_BAWZkRn2K8l1dYXVc3Am7i3PAZFlUxHwWtsL95EjHE6g/file
# Resolving ucd4ee8b4a27d469b30a12f45096.dl.dropboxusercontent.com (ucd4ee8b4a27d469b30a12f45096.dl.dropboxusercontent.com)... 162.125.4.15, 2620:100:6019:15::a27d:40f
# Connecting to ucd4ee8b4a27d469b30a12f45096.dl.dropboxusercontent.com (ucd4ee8b4a27d469b30a12f45096.dl.dropboxusercontent.com)|162.125.4.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/Br0JRxhkcIHN34XfwC2d1CTwj_yiKOUXf_jNhLsZuHJ9HF0Jd9R7ubKF-wzMZ9lsDEdD_j-PdgQcizSYF2jyxQGEBA9QQJKd_jdg3A-c-FgCjaoeorjeFFSNvgDIraAC41_TFazyiRGlXnc2ZoyVakHBrUhC-KpFGYDz_A0yEhS2M8cFKsz1qftHpXrpTSBT20RAK8MiDusF2H3exxuYmvRRqwAonjHIwM77McxgMuzKHN1e-_dXtrYzKRWE3qfCQ4Qrh9tvuupuSWXX-jTRtfFq8FsJv00VsQMcXpn3rjN2PrkMixW7KHkR6NDqcd6I92aKYNxezo0AAU27ayCubfKC_Yil6dXpU9O34x0Q5B6uQ_UYjBj89LKK4RP_WGRMqoEsxspd6YaIm8wn27CZuxx43_MuczsYcNy7zCglwMrF4Q/file [following]
# --2022-08-27 23:33:48--  https://ucd4ee8b4a27d469b30a12f45096.dl.dropboxusercontent.com/cd/0/inline2/Br0JRxhkcIHN34XfwC2d1CTwj_yiKOUXf_jNhLsZuHJ9HF0Jd9R7ubKF-wzMZ9lsDEdD_j-PdgQcizSYF2jyxQGEBA9QQJKd_jdg3A-c-FgCjaoeorjeFFSNvgDIraAC41_TFazyiRGlXnc2ZoyVakHBrUhC-KpFGYDz_A0yEhS2M8cFKsz1qftHpXrpTSBT20RAK8MiDusF2H3exxuYmvRRqwAonjHIwM77McxgMuzKHN1e-_dXtrYzKRWE3qfCQ4Qrh9tvuupuSWXX-jTRtfFq8FsJv00VsQMcXpn3rjN2PrkMixW7KHkR6NDqcd6I92aKYNxezo0AAU27ayCubfKC_Yil6dXpU9O34x0Q5B6uQ_UYjBj89LKK4RP_WGRMqoEsxspd6YaIm8wn27CZuxx43_MuczsYcNy7zCglwMrF4Q/file
# Reusing existing connection to ucd4ee8b4a27d469b30a12f45096.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 135550056 (129M) [application/octet-stream]
# Saving to: ‘data/two_algo_face_rotator.pt’
#
# data/two_algo_face_ 100%[===================>] 129.27M  65.2MB/s    in 2.0s
#
# 2022-08-27 23:33:50 (65.2 MB/s) - ‘data/two_algo_face_rotator.pt’ saved [135550056/135550056]

# %%
import PIL.Image
import io
from io import StringIO, BytesIO
import IPython.display
import numpy
import ipywidgets
from tha2.util import extract_PIL_image_from_filelike, resize_PIL_image, extract_pytorch_image_from_PIL_image, convert_output_image_from_torch_to_numpy
import tha2.poser.modes.mode_20
import time
import threading
import torch

FRAME_RATE = 30.0
DEVICE_NAME = 'cuda'
device = torch.device(DEVICE_NAME)

last_torch_input_image = None
torch_input_image = None

def show_pytorch_image(pytorch_image, output_widget=None):
    output_image = pytorch_image.detach().cpu()
    numpy_image = numpy.uint8(numpy.rint(convert_output_image_from_torch_to_numpy(output_image) * 255.0))
    pil_image = PIL.Image.fromarray(numpy_image, mode='RGBA')
    IPython.display.display(pil_image)

input_image_widget = ipywidgets.Output(
    layout={
        'border': '1px solid black',
        'width': '256px',
        'height': '256px'
    })

upload_input_image_button = ipywidgets.FileUpload(
    accept='.png',
    multiple=False,
    layout={
        'width': '256px'
    }
)

output_image_widget = ipywidgets.Output(
    layout={
        'border': '1px solid black',
        'width': '256px',
        'height': '256px'
    }
)

eyebrow_dropdown = ipywidgets.Dropdown(
    options=["troubled", "angry", "lowered", "raised", "happy", "serious"],
    value="troubled",
    description="Eyebrow:",    
)
eyebrow_left_slider = ipywidgets.FloatSlider(
    value=0.0,
    min=0.0,
    max=1.0,
    step=0.01,
    description="Left:",
    readout=True,
    readout_format=".2f"
)
eyebrow_right_slider = ipywidgets.FloatSlider(
    value=0.0,
    min=0.0,
    max=1.0,
    step=0.01,
    description="Right:",
    readout=True,
    readout_format=".2f"
)

eye_dropdown = ipywidgets.Dropdown(
    options=["wink", "happy_wink", "surprised", "relaxed", "unimpressed", "raised_lower_eyelid"],
    value="wink",
    description="Eye:",    
)
eye_left_slider = ipywidgets.FloatSlider(
    value=0.0,
    min=0.0,
    max=1.0,
    step=0.01,
    description="Left:",
    readout=True,
    readout_format=".2f"
)
eye_right_slider = ipywidgets.FloatSlider(
    value=0.0,
    min=0.0,
    max=1.0,
    step=0.01,
    description="Right:",
    readout=True,
    readout_format=".2f"
)

mouth_dropdown = ipywidgets.Dropdown(
    options=["aaa", "iii", "uuu", "eee", "ooo", "delta", "lowered_corner", "raised_corner", "smirk"],
    value="aaa",
    description="Mouth:",    
)
mouth_left_slider = ipywidgets.FloatSlider(
    value=0.0,
    min=0.0,
    max=1.0,
    step=0.01,
    description="Value:",
    readout=True,
    readout_format=".2f"
)
mouth_right_slider = ipywidgets.FloatSlider(
    value=0.0,
    min=0.0,
    max=1.0,
    step=0.01,
    description=" ",
    readout=True,
    readout_format=".2f",
    disabled=True,
)

def update_mouth_sliders(change):
    if mouth_dropdown.value == "lowered_corner" or mouth_dropdown.value == "raised_corner":
        mouth_left_slider.description = "Left:"
        mouth_right_slider.description = "Right:"
        mouth_right_slider.disabled = False
    else:
        mouth_left_slider.description = "Value:"
        mouth_right_slider.description = " "
        mouth_right_slider.disabled = True

mouth_dropdown.observe(update_mouth_sliders, names='value')

iris_small_left_slider = ipywidgets.FloatSlider(
    value=0.0,
    min=0.0,
    max=1.0,
    step=0.01,
    description="Left:",
    readout=True,
    readout_format=".2f"
)
iris_small_right_slider = ipywidgets.FloatSlider(
    value=0.0,
    min=0.0,
    max=1.0,
    step=0.01,
    description="Right:",
    readout=True,
    readout_format=".2f",    
)
iris_rotation_x_slider = ipywidgets.FloatSlider(
    value=0.0,
    min=-1.0,
    max=1.0,
    step=0.01,
    description="X-axis:",
    readout=True,
    readout_format=".2f"
)
iris_rotation_y_slider = ipywidgets.FloatSlider(
    value=0.0,
    min=-1.0,
    max=1.0,
    step=0.01,
    description="Y-axis:",
    readout=True,
    readout_format=".2f",    
)

head_x_slider = ipywidgets.FloatSlider(
    value=0.0,
    min=-1.0,
    max=1.0,
    step=0.01,
    description="X-axis:",
    readout=True,
    readout_format=".2f"
)
head_y_slider = ipywidgets.FloatSlider(
    value=0.0,
    min=-1.0,
    max=1.0,
    step=0.01,
    description="Y-axis:",
    readout=True,
    readout_format=".2f",    
)
neck_z_slider = ipywidgets.FloatSlider(
    value=0.0,
    min=-1.0,
    max=1.0,
    step=0.01,
    description="Z-axis:",
    readout=True,
    readout_format=".2f",    
)


control_panel = ipywidgets.VBox([
    eyebrow_dropdown,
    eyebrow_left_slider,
    eyebrow_right_slider,
    ipywidgets.HTML(value="<hr>"),
    eye_dropdown,
    eye_left_slider,
    eye_right_slider,
    ipywidgets.HTML(value="<hr>"),
    mouth_dropdown,
    mouth_left_slider,
    mouth_right_slider,
    ipywidgets.HTML(value="<hr>"),
    ipywidgets.HTML(value="<center><b>Iris Shrinkage</b></center>"),
    iris_small_left_slider,
    iris_small_right_slider,
    ipywidgets.HTML(value="<center><b>Iris Rotation</b></center>"),
    iris_rotation_x_slider,
    iris_rotation_y_slider,
    ipywidgets.HTML(value="<hr>"),
    ipywidgets.HTML(value="<center><b>Head Rotation</b></center>"),
    head_x_slider,
    head_y_slider,
    neck_z_slider,
])

controls = ipywidgets.HBox([
    ipywidgets.VBox([
        input_image_widget, 
        upload_input_image_button
    ]),
    control_panel,
    ipywidgets.HTML(value="&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;"),
    output_image_widget,
])

poser = tha2.poser.modes.mode_20.create_poser(device)
pose_parameters = tha2.poser.modes.mode_20.get_pose_parameters()
pose_size = poser.get_num_parameters()
last_pose = torch.zeros(1, pose_size).to(device)

iris_small_left_index = pose_parameters.get_parameter_index("iris_small_left")
iris_small_right_index = pose_parameters.get_parameter_index("iris_small_right")
iris_rotation_x_index = pose_parameters.get_parameter_index("iris_rotation_x")
iris_rotation_y_index = pose_parameters.get_parameter_index("iris_rotation_y")
head_x_index = pose_parameters.get_parameter_index("head_x")
head_y_index = pose_parameters.get_parameter_index("head_y")
neck_z_index = pose_parameters.get_parameter_index("neck_z")

def get_pose():
    pose = torch.zeros(1, pose_size)

    eyebrow_name = f"eyebrow_{eyebrow_dropdown.value}"
    eyebrow_left_index = pose_parameters.get_parameter_index(f"{eyebrow_name}_left")
    eyebrow_right_index = pose_parameters.get_parameter_index(f"{eyebrow_name}_right")
    pose[0, eyebrow_left_index] = eyebrow_left_slider.value
    pose[0, eyebrow_right_index] = eyebrow_right_slider.value

    eye_name = f"eye_{eye_dropdown.value}"
    eye_left_index = pose_parameters.get_parameter_index(f"{eye_name}_left")
    eye_right_index = pose_parameters.get_parameter_index(f"{eye_name}_right")
    pose[0, eye_left_index] = eye_left_slider.value
    pose[0, eye_right_index] = eye_right_slider.value

    mouth_name = f"mouth_{mouth_dropdown.value}"
    if mouth_name == "mouth_lowered_corner" or mouth_name == "mouth_raised_corner":
        mouth_left_index = pose_parameters.get_parameter_index(f"{mouth_name}_left")
        mouth_right_index = pose_parameters.get_parameter_index(f"{mouth_name}_right")
        pose[0, mouth_left_index] = mouth_left_slider.value
        pose[0, mouth_right_index] = mouth_right_slider.value
    else:
        mouth_index = pose_parameters.get_parameter_index(mouth_name)
        pose[0, mouth_index] = mouth_left_slider.value

    pose[0, iris_small_left_index] = iris_small_left_slider.value
    pose[0, iris_small_right_index] = iris_small_right_slider.value
    pose[0, iris_rotation_x_index] = iris_rotation_x_slider.value
    pose[0, iris_rotation_y_index] = iris_rotation_y_slider.value
    pose[0, head_x_index] = head_x_slider.value
    pose[0, head_y_index] = head_y_slider.value
    pose[0, neck_z_index] = neck_z_slider.value

    return pose.to(device)

display(controls)

def update(change):
    global last_pose
    global last_torch_input_image

    if torch_input_image is None:
        return

    needs_update = False
    if last_torch_input_image is None:
        needs_update = True        
    else:
        if (torch_input_image - last_torch_input_image).abs().max().item() > 0:
            needs_update = True         

    pose = get_pose()
    if (pose - last_pose).abs().max().item() > 0:
        needs_update = True

    if not needs_update:
        return

    output_image = poser.pose(torch_input_image, pose)[0]
    with output_image_widget:
        output_image_widget.clear_output(wait=True)
        show_pytorch_image(output_image, output_image_widget)  

    last_torch_input_image = torch_input_image
    last_pose = pose

def upload_image(change):
    global torch_input_image
    for name, file_info in upload_input_image_button.value.items():
        content = io.BytesIO(file_info['content'])
    if content is not None:
        pil_image = resize_PIL_image(extract_PIL_image_from_filelike(content))
        w, h = pil_image.size
        if pil_image.mode != 'RGBA':
            with input_image_widget:
                input_image_widget.clear_output(wait=True)
                display(ipywidgets.HTML("Image must have an alpha channel!!!"))
        else:
            torch_input_image = extract_pytorch_image_from_PIL_image(pil_image).to(device)
            with input_image_widget:
                input_image_widget.clear_output(wait=True)
                show_pytorch_image(torch_input_image, input_image_widget)
        update(None)

upload_input_image_button.observe(upload_image, names='value')
eyebrow_dropdown.observe(update, 'value')
eyebrow_left_slider.observe(update, 'value')
eyebrow_right_slider.observe(update, 'value')
eye_dropdown.observe(update, 'value')
eye_left_slider.observe(update, 'value')
eye_right_slider.observe(update, 'value')
mouth_dropdown.observe(update, 'value')
mouth_left_slider.observe(update, 'value')
mouth_right_slider.observe(update, 'value')
iris_small_left_slider.observe(update, 'value')
iris_small_right_slider.observe(update, 'value')
iris_rotation_x_slider.observe(update, 'value')
iris_rotation_y_slider.observe(update, 'value')
head_x_slider.observe(update, 'value')
head_y_slider.observe(update, 'value')
neck_z_slider.observe(update, 'value')
# Out:
# HBox(children=(VBox(children=(Output(layout=Layout(border='1px solid black', height='256px', width='256px')), …
